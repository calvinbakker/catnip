# %%
import numpy as np
import sys
sys.path.append('../../modules/') 
from rule import *
from visual import *
from vecnum import *


rule = 7
order = 1

string = get_string(rule)
print(string)

map = get_map(rule,order)
print(map)

# matrix = rule_matrix(rule,order)
# print(matrix)

# vector = np.array([0,1,0,0])
# print(matrix@vector)
# Out:
# 111
# [1, 1, 1, 0]

# %%
sites       = order+1
matrix      = rule_matrix(rule,order)
for state in range(2**(order+1)):
    in_state    = number_to_bit_array(state,sites)
    in_arr      = bit_array_to_vector(in_state)
    out_arr     = matrix@in_arr
    out_state   = vector_to_bit_array(out_arr,sites)

    # print(in_state,in_arr)
    # print(out_state,out_arr)
    # print()

    print(in_state)
    print([out_state[0]])
    print()
# Out:
# [0 0]
# [1]
#
# [1 0]
# [1]
#
# [0 1]
# [1]
#
# [1 1]
# [0]
