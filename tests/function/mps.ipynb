# %%
import numpy as np
import sys
sys.path.append('../../modules/') 
from config import hsd, num_threshold
from tensor import *
from vecnum import *

array = [1,2,0,0]
rule = 6
order = 1 


state = create_mps(array)
print(np.allclose(bonds_of_mpo(state),1))

L = [np.rint(np.where(np.abs(x.ravel())==1)[0][0]) for x in state]
print(L)
# Out:
# True
# [1.0, 2.0, 0.0, 0.0]

# %%
print(state2) 
# L = []
# for x in np.nonzero(state):
#     coef = state[x]
#     array = number_to_bit_array(x)
#     L.append([coef,array])

# for l in L:
#     print(l[0],l[1])
# Out:
# [array([[ 0.        ,  0.70710678],
#        [-0.70710678,  0.        ]]), array([[[ 1.,  0.],
#         [ 0.,  0.]],
#
#        [[ 0., -1.],
#         [ 0.,  0.]]]), array([[[ 1.,  0.],
#         [ 0.,  0.]],
#
#        [[ 0., -1.],
#         [ 0.,  0.]]]), array([[-1.41421356,  0.        ],
#        [ 0.        ,  0.        ]])]
