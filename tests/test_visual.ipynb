# %%
import numpy as np
import sys
sys.path.append('../modules/') 
from visual import *
from config import hsd
from rule import random_rule

order   = 3
sites   = 1800
# rule    = 6
# array   = np.array(5*[0]+[1])

rule    = random_rule(order)
array   = np.random.randint(0,hsd,size=sites)
timesteps = 1800


print("👽 rule:",rule)
# show_rule(rule,order)

time_evolution_bit(rule,order,array.copy(),timesteps,"bit")
# time_evolution_mps_array(rule,order,array.copy(),timesteps,"mps_array")
# time_evolution_mpo_matrix(rule,order,array.copy(),timesteps,"mpo_matrix")
# time_evolution_mps(rule,order,array.copy(),timesteps,"mps")
# Out:
# 👽 rule: 14828
